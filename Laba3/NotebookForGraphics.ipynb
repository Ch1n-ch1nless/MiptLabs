# %%
import pandas as pd
import matplotlib.pyplot as plt

# Загрузка данных из входного файла .txt
data1 = pd.read_csv('TimeFiles/bubble_sort_time.csv', sep=';', header=None, names=['n', 'time'])
data2 = pd.read_csv('TimeFiles/insertion_sort_time.csv', sep=';', header=None, names=['n', 'time'])
data3 = pd.read_csv('TimeFiles/selection_sort_time.csv', sep=';', header=None, names=['n', 'time'])
data4 = pd.read_csv('TimeFiles/shell_sort_time.csv', sep=';', header=None, names=['n', 'time'])

# Построение графика
plt.plot(data1['n'], data1['time'], '-', data2['n'], data2['time'], '--', data3['n'], data3['time'], '-.', data4['n'], data4['time'], ':')
plt.xlabel('Number of insertions')
plt.ylabel('Time taken (microsec)')
plt.legend(('bubble sort', 'insertion sort', 'selection sort', 'shell sort'))
plt.title('Quadratic sorts and one cooler:)')
plt.savefig('punct1.png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Загрузка данных из входного файла .txt
data1 = pd.read_csv('TimeFiles/heap_sort_2_0.csv', sep=';', header=None, names=['n', 'time'])
data2 = pd.read_csv('TimeFiles/heap_sort_3_0.csv', sep=';', header=None, names=['n', 'time'])
data3 = pd.read_csv('TimeFiles/heap_sort_4_0.csv', sep=';', header=None, names=['n', 'time'])
data4 = pd.read_csv('TimeFiles/heap_sort_5_0.csv', sep=';', header=None, names=['n', 'time'])

# Построение графика
plt.plot(data1['n'], data1['time'], '-', data2['n'], data2['time'], '--', data3['n'], data3['time'], '-.', data4['n'], data4['time'], ':')
plt.xlabel('Number of insertions')
plt.ylabel('Time taken (microsec)')
plt.legend(('Size = 2', 'Size = 3', 'Size = 4', 'Size = 5'))
plt.title('Heap sort based on k-ary heap')
plt.savefig('Images/punct2_1.png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Загрузка данных из входного файла .txt
data1 = pd.read_csv('TimeFiles/heap_sort_6_0.csv', sep=';', header=None, names=['n', 'time'])
data2 = pd.read_csv('TimeFiles/heap_sort_7_0.csv', sep=';', header=None, names=['n', 'time'])
data3 = pd.read_csv('TimeFiles/heap_sort_8_0.csv', sep=';', header=None, names=['n', 'time'])
data4 = pd.read_csv('TimeFiles/heap_sort_9_0.csv', sep=';', header=None, names=['n', 'time'])

# Построение графика
plt.plot(data1['n'], data1['time'], '-', data2['n'], data2['time'], '--', data3['n'], data3['time'], '-.', data4['n'], data4['time'], ':')
plt.xlabel('Number of insertions')
plt.ylabel('Time taken (microsec)')
plt.legend(('Size = 6', 'Size = 7', 'Size = 8', 'Size = 9'))
plt.title('Heap sort based on k-ary heap')
plt.savefig('Images/punct2_2.png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Загрузка данных из входного файла .txt
data1 = pd.read_csv('TimeFiles/heap_sort_4_0.csv', sep=';', header=None, names=['n', 'time'])
data2 = pd.read_csv('TimeFiles/heap_sort_5_0.csv', sep=';', header=None, names=['n', 'time'])
data3 = pd.read_csv('TimeFiles/heap_sort_6_0.csv', sep=';', header=None, names=['n', 'time'])

# Построение графика
plt.plot(data1['n'], data1['time'], '-', data2['n'], data2['time'], '--', data3['n'], data3['time'], '-.')
plt.xlabel('Number of insertions')
plt.ylabel('Time taken (microsec)')
plt.legend(('Size = 4', 'Size = 5', 'Size = 6'))
plt.title('Heap sort based on k-ary heap')
plt.savefig('Images/punct2_3.png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Загрузка данных из входного файла .txt
data1 = pd.read_csv('TimeFiles/iter_merge_sort_time.csv', sep=';', header=None, names=['n', 'time'])
data2 = pd.read_csv('TimeFiles/rec_merge_sort_time.csv', sep=';', header=None, names=['n', 'time'])

# Построение графика
plt.plot(data1['n'], data1['time'], '-', data2['n'], data2['time'], '--')
plt.xlabel('Number of insertions')
plt.ylabel('Time taken (milliseconds)')
plt.legend(('Iterative Merge Sort', 'Recursive Merge Sort'))
plt.title('Сomparison of iterative and recursive implementation of merge sort')
plt.savefig('Images/punct3.png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Загрузка данных из входного файла .txt
data1 = pd.read_csv('TimeFiles/lomuto_partition_time_no_dub.csv', sep=';', header=None, names=['n', 'time'])
data2 = pd.read_csv('TimeFiles/hoar_partition_1_time_no_dub.csv', sep=';', header=None, names=['n', 'time'])
data3 = pd.read_csv('TimeFiles/hoar_partition_2_time_no_dub.csv', sep=';', header=None, names=['n', 'time'])
data4 = pd.read_csv('TimeFiles/flag_partition_time_no_dub.csv', sep=';', header=None, names=['n', 'time'])

# Построение графика
plt.plot(data1['n'], data1['time'], '-', data2['n'], data2['time'], '--', data3['n'], data3['time'], '-.', data4['n'], data4['time'], ':')
plt.xlabel('Number of insertions')
plt.ylabel('Time taken (microseconds)')
plt.legend(('Lomuto partition', 'Hoar partition with only 1 rec. branch', 'Hoar partition with 2 rec. branches', 'Flag partition'))
plt.title('Comparing partitions in QuickSort (no dublicates)')
plt.savefig('Images/punct4_1.png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Загрузка данных из входного файла .csv
data1 = pd.read_csv('TimeFiles/lomuto_partition_time_dub.csv', sep=';', header=None, names=['n', 'time'])
data2 = pd.read_csv('TimeFiles/hoar_partition_1_time_dub.csv', sep=';', header=None, names=['n', 'time'])
data3 = pd.read_csv('TimeFiles/hoar_partition_2_time_dub.csv', sep=';', header=None, names=['n', 'time'])
data4 = pd.read_csv('TimeFiles/flag_partition_time_dub.csv', sep=';', header=None, names=['n', 'time'])

# Построение графика
plt.plot(data1['n'], data1['time'], '-', data2['n'], data2['time'], '--', data3['n'], data3['time'], '-.', data4['n'], data4['time'], ':')
plt.xlabel('Number of insertions')
plt.ylabel('Time taken (microseconds)')
plt.legend(('Lomuto partition', 'Hoar partition with only 1 rec. branch', 'Hoar partition with 2 rec. branches', 'Flag partition'))
plt.title('Comparing partitions in QuickSort (with dublicates)')
plt.savefig('Images/punct4_2.png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Загрузка данных из входного файла .csv
data1 = pd.read_csv('TimeFiles/central_pivot_time.csv', sep=';', header=None, names=['n', 'time'])
data2 = pd.read_csv('TimeFiles/median_time.csv', sep=';', header=None, names=['n', 'time'])
data3 = pd.read_csv('TimeFiles/random_pivot_time.csv', sep=';', header=None, names=['n', 'time'])
data4 = pd.read_csv('TimeFiles/median_of_3_random_elems_time.csv', sep=';', header=None, names=['n', 'time'])

# Построение графика
plt.plot(data1['n'], data1['time'], '-', data2['n'], data2['time'], '--', data3['n'], data3['time'], '-.', data4['n'], data4['time'], ':')
plt.xlabel('Number of insertions')
plt.ylabel('Time taken (microseconds)')
plt.legend(('Central element', 'Median of 3 elements', 'Random element', 'Median of 3 random elements'))
plt.title('Pivot selection strategies')
plt.savefig('Images/punct5.png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Загрузка данных из входного файла .csv
data1 = pd.read_csv('TimeFiles/quick_sort_block_time.csv', sep=';', header=None, names=['n', 'time'])
data2 = pd.read_csv('TimeFiles/shell_sort_block_time.csv', sep=';', header=None, names=['n', 'time'])

# Построение графика
plt.plot(data1['n'], data1['time'], '-', data2['n'], data2['time'], '--')
plt.xlabel('Number of insertions')
plt.ylabel('Time taken (microseconds)')
plt.legend(('Quick sort', 'Shell sort'))
plt.title('Selecting block size for "IntroSort"')
plt.savefig('Images/punct6.png')
plt.show()
